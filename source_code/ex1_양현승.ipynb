# %%
import pandas as pd

# %%
ac = pd.read_csv('../data/ex1.csv', encoding='utf-8')
ac.head()
# Out:
#        timestamp      AccX
# 0  1583482661137 -0.581809
# 1  1583482661185 -0.004789
# 2  1583482661244 -0.423787
# 3  1583482661303  0.067040
# 4  1583482661304 -0.052674

# %%
ac.columns
# Out:
# Index(['timestamp', 'AccX'], dtype='object')

# %%
ac.columns[0]
# Out:
# 'timestamp'

# %%
ac.rename(columns={ac.columns[0]:'시간', ac.columns[1]:'선형가속도'}, inplace=True)
ac.head()
# Out:
#               시간     선형가속도
# 0  1583482661137 -0.581809
# 1  1583482661185 -0.004789
# 2  1583482661244 -0.423787
# 3  1583482661303  0.067040
# 4  1583482661304 -0.052674

# %%
ac.describe()
# Out:
#                  시간       선형가속도
# count  3.820000e+02  382.000000
# mean   1.583483e+12    6.471794
# std    5.112960e+03    4.626602
# min    1.583483e+12   -4.666441
# 25%    1.583483e+12    3.416630
# 50%    1.583483e+12    6.384334
# 75%    1.583483e+12    9.812935
# max    1.583483e+12   16.695278

# %%
ac.sort_values(by='선형가속도', ascending=False).head()
# Out:
#                 시간      선형가속도
# 189  1583482670304  16.695278
# 191  1583482670424  16.233183
# 190  1583482670364  16.087132
# 186  1583482670125  16.087132
# 192  1583482670425  15.890801

# %%
ac.sort_values(by='선형가속도', ascending=True).head()
# Out:
#                시간     선형가속도
# 36  1583482662864 -4.666441
# 56  1583482663765 -3.960130
# 35  1583482662805 -3.328042
# 37  1583482662925 -3.043123
# 57  1583482663824 -2.846793

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import platform
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus']=False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
    
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
    
else:
    print('Unknown system!')

# %%
plt.plot(ac['시간'], ac['선형가속도'])
plt.show()

# %%
plt.plot(ac['시간'], ac['선형가속도'])
plt.title('선형가속도계')
plt.xlabel('시간')
plt.ylabel('선형가속도')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(ac['시간'], ac['선형가속도'])
plt.grid()
plt.title('선형가속도계')
plt.xlabel('시간')
plt.ylabel('선형가속도')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(ac['시간'], ac['선형가속도'], color='green', linestyle='dashed', marker='o')
plt.title('선형가속도계')
plt.grid()
plt.xlabel('시간')
plt.ylabel('선형가속도')
plt.show()
